# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('clean_data_science_jobs_2.csv')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0                                     Data Scientist
# 1  Data Scientist / Machine learning/scRNASeq dat...
# 2                             Data Scientist Trainee
# 3  Data Scientist(RNAseq,Genomics,Omnics,Machine ...
# 4                                     Data Scientist
#
#                                      Salary Estimate  \
# 0  Employer Provided Salary:$55.00 - $65.00 Per Hour
# 1  Employer Provided Salary:$40.00 - $50.00 Per Hour
# 2                      $74K - $114K (Glassdoor est.)
# 3  Employer Provided Salary:$51.00 - $52.00 Per Hour
# 4                      $79K - $122K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Job Description-\nDesign, develop, optimize, a...    -1.0
# 1  Job Description:\nResponsibilities:\nProject i...     3.7
# 2  Overview:\nAxle Informatics is a scientific re...     3.5
# 3  Job Description:\nResponsibilities:\nProject i...     3.7
# 4  Career Area:\nInformation Analytics\nJob Descr...     4.0
#
#               Company Name       Location  Headquarters  \
# 0  NLB Technology Services         Remote            -1
# 1     TellusSolutions\n3.7         Remote            -1
# 2    Axle Informatics\n3.5  Rockville, MD            -1
# 3    Tellus Solutions\n3.7         Remote            -1
# 4         Caterpillar\n4.0     Peoria, IL            -1
#
#                     Size  Founded  Type of ownership  ... python_yn  \
# 0                Unknown       -1   Company - Public  ...         0
# 1    51 to 200 Employees     2006  Company - Private  ...         0
# 2  501 to 1000 Employees     2002  Company - Private  ...         0
# 3    51 to 200 Employees     2006  Company - Private  ...         0
# 4       10000+ Employees     1925   Company - Public  ...         0
#
#   rstudio_yn spark_yn  aws_yn  excel_yn        job_simp  seniority  desc_len  \
# 0          0        0       0         0  data scientist         na       765
# 1          0        0       0         0  data scientist         na       647
# 2          0        0       0         0  data scientist         na       932
# 3          0        0       0         0  data scientist         na       647
# 4          0        0       0         0  data scientist         na       476
#
#   avg_salary              company_txt
# 0      120.0  NLB Technology Services
# 1       90.0          TellusSolutions
# 2       94.0         Axle Informatics
# 3      103.0         Tellus Solutions
# 4      100.5              Caterpillar
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary', 'company_txt'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Rating  Headquarters      Founded  Competitors      hourly  \
# count  783.000000         783.0   783.000000        783.0  783.000000
# mean     3.620307          -1.0  1719.988506         -1.0    0.044700
# std      1.120814           0.0   645.609160          0.0    0.206776
# min     -1.000000          -1.0    -1.000000         -1.0    0.000000
# 25%      3.500000          -1.0  1896.000000         -1.0    0.000000
# 50%      3.900000          -1.0  1962.000000         -1.0    0.000000
# 75%      4.000000          -1.0  2004.000000         -1.0    0.000000
# max      5.000000          -1.0  2017.000000         -1.0    1.000000
#
#        employer_provided  min_salary  max_salary         age   python_yn  \
# count         783.000000  783.000000  783.000000  783.000000  783.000000
# mean            0.638570  100.065134  150.409962   54.735632    0.107280
# std             0.480722   31.217242   53.384737   53.295373    0.309666
# min             0.000000   54.000000   60.000000   -1.000000    0.000000
# 25%             0.000000   79.000000  113.000000    9.000000    0.000000
# 50%             1.000000   92.000000  135.000000   27.000000    0.000000
# 75%             1.000000  114.000000  170.000000  100.000000    0.000000
# max             1.000000  187.000000  332.000000  269.000000    1.000000
#
#        rstudio_yn    spark_yn      aws_yn    excel_yn     desc_len  avg_salary
# count       783.0  783.000000  783.000000  783.000000   783.000000  783.000000
# mean          0.0    0.003831    0.030651    0.089400  1312.948914  125.237548
# std           0.0    0.061819    0.172481    0.285502  1032.617675   40.391685
# min           0.0    0.000000    0.000000    0.000000   105.000000   57.500000
# 25%           0.0    0.000000    0.000000    0.000000   734.000000   98.000000
# 50%           0.0    0.000000    0.000000    0.000000   939.000000  115.000000
# 75%           0.0    0.000000    0.000000    0.000000  1453.000000  139.000000
# max           0.0    1.000000    1.000000    1.000000  5832.000000  242.500000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary', 'company_txt'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['age','avg_salary','Rating'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Rating')
# Out:
# <AxesSubplot:>

# %%
corr_df= df[['age','avg_salary','Rating', 'desc_len']].corr()

# %%
cmap = sns.diverging_palette(220,10,as_cmap=True)

sns.heatmap(corr_df,cmap=cmap, vmax=.3, center=0,
           square=True, linewidths=.5,cbar_kws={"shrink":.5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary', 'company_txt'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'job_state', 'company_text', 'python_yn', 'rstudio_yn',
       'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()

# %%
for i in df_cat[['Location', 'company_text']]:
    cat_num = df_cat[i].value_counts()[:20]
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary', 'company_txt'],
#       dtype='object')

# %%
pd.pivot_table(df, index='job_simp', values='avg_salary')
# Out:
#                 avg_salary
# job_simp
# data scientist  125.288092
# na              105.500000

# %%
pd.pivot_table(df, index=['job_simp', 'seniority'], values='avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# data scientist jr          85.307692
#                na         122.118280
#                senior     155.125000
# na             na         105.500000

# %%
pd.pivot_table(df, index=['job_state', 'seniority'], values='avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                            avg_salary
# job_state       seniority
#  Remote         senior     215.500000
#  California     na         215.000000
#  TX             senior     212.000000
#  DC             na         190.000000
#  NY             senior     160.000000
#  CA             senior     157.197368
#                 na         149.566667
#  WA             na         144.714286
#  NY             na         142.141026
#  North Carolina senior     135.000000
#  MD             na         130.948276
#  AZ             na         130.513514
#  MN             senior     124.000000
#  Remote         na         122.793333
#  AL             na         120.000000
#  MA             na         119.100000
#  IL             senior     116.500000
#  NJ             senior     116.000000
#  FL             senior     113.189655
#  RI             na         110.000000
#  VA             na         109.472222
#  TX             na         104.687500
#  IA             na         103.500000
#  IL             na         101.681818
#  NJ             na         100.322581
#  United States  na         100.000000
#  NC             na          98.821429
#  MI             na          98.000000
#  PA             na          97.333333
#  FL             na          96.900000
#  MO             na          96.000000
#  NJ             jr          95.000000
#  MN             na          90.000000
#  OH             na          87.770833
#  CA             jr          84.500000
#  CT             na          84.000000
#  MS             na          69.000000
#  WI             na          59.692308

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary', 'company_txt'],
#       dtype='object')

# %%
#rating, industry, sector, revenue, number of comp, hourly, employer provided, pytho, r, spark, aws, excel, Type of ournership
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided', 'python_yn', 'rstudio_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'Type of ownership', 'avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index=i, values='avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
#  4.8    207.500000
#  3.6    182.282609
#  3.7    147.347561
#  4.4    146.875000
#  4.3    145.306122
# -1.0    133.384615
#  3.9    129.985795
#  4.5    119.400000
#  2.8    119.000000
#  4.1    118.465909
#  4.2    116.300000
#  3.1    108.538462
#  3.4    107.170213
#  3.5    105.282178
#  5.0    104.500000
#  3.8    100.764706
#  4.9     98.800000
#  4.0     97.706349
#  3.3     96.384615
# Industry
#                                          avg_salary
# Industry
# Real Estate                              210.595238
# Enterprise Software & Network Solutions  203.750000
# Software Development                     193.125000
# Internet & Web Services                  153.309735
# Telecommunications Services              144.500000
# National Agencies                        137.066667
# Ticket Sales                             135.000000
# Biotech & Pharmaceuticals                132.687500
# Aerospace & Defense                      131.838710
# Department, Clothing & Shoe Stores       121.000000
# Shipping & Trucking                      120.000000
# Accounting & Tax                         120.000000
# Insurance Agencies & Brokerages          119.000000
# Financial Transaction Processing         116.000000
# Health Care Products Manufacturing       116.000000
# Film Production                          114.500000
# Grocery Stores                           114.000000
# Transportation Equipment Manufacturing   112.875000
# -1                                       112.756944
# Banking & Lending                        111.500000
# Research & Development                   110.500000
# Business Consulting                      109.562500
# Computer Hardware Development            108.257143
# Food & Beverage Manufacturing            107.500000
# Information Technology Support Services  105.493243
# Insurance Carriers                       102.677778
# Health Care Services & Hospitals         101.620690
# Machinery Manufacturing                  101.000000
# Construction                             100.000000
# Home Furniture & Housewares Stores        98.000000
# Drug & Health Stores                      98.000000
# Sporting Goods Stores                     94.500000
# Municipal Agencies                        90.000000
# Metal & Mineral Manufacturing             90.000000
# Other Retail Stores                       90.000000
# Consumer Product Manufacturing            84.000000
# Colleges & Universities                   78.416667
# Sector
#                                              avg_salary
# Sector
# Real Estate                                  210.595238
# Telecommunications                           144.500000
# Information Technology                       144.275000
# Arts, Entertainment & Recreation             135.000000
# Pharmaceutical & Biotechnology               132.687500
# Aerospace & Defense                          131.838710
# Transportation & Logistics                   120.000000
# Government & Public Administration           115.672727
# Financial Services                           114.642857
# Media & Communication                        114.500000
# -1                                           112.756944
# Management & Consulting                      109.818182
# Retail & Wholesale                           109.443182
# Manufacturing                                103.760417
# Insurance                                    103.032609
# Healthcare                                   101.620690
# Construction, Repair & Maintenance Services  100.000000
# Education                                     78.416667
# Revenue
#                                   avg_salary
# Revenue
# -1                                157.291667
# $500 million to $1 billion (USD)  152.218750
# $25 to $100 million (USD)         134.294118
# $5 to $10 billion (USD)           130.633333
# Unknown / Non-Applicable          129.030303
# $1 to $5 billion (USD)            125.822222
# $10+ billion (USD)                120.902256
# $1 to $5 million (USD)            111.500000
# Less than $1 million (USD)        101.000000
# $5 to $25 million (USD)            95.928571
# $100 to $500 million (USD)         94.840909
# hourly
#         avg_salary
# hourly
# 0       125.725936
# 1       114.800000
# employer_provided
#                    avg_salary
# employer_provided
# 1                  135.183000
# 0                  107.666078
# python_yn
#            avg_salary
# python_yn
# 0          129.713877
# 1           87.988095
# rstudio_yn
#             avg_salary
# rstudio_yn
# 0           125.237548
# spark_yn
#           avg_salary
# spark_yn
# 1         143.333333
# 0         125.167949
# aws_yn
#         avg_salary
# aws_yn
# 1       169.437500
# 0       123.839921
# excel_yn
#           avg_salary
# excel_yn
# 0         125.783310
# 1         119.678571
# Type of ownership
#                                 avg_salary
# Type of ownership
# -1                              157.291667
# Company - Private               141.397059
# Company - Public                128.467337
# Government                      115.672727
# Unknown                         100.000000
# Nonprofit Organization           95.690141
# Self-employed                    89.250000
# College / University             78.416667
# Subsidiary or Business Segment   65.000000
# avg_salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21196\52483973.py in <module>
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots, index=i, values='avg_salary').sort_values('avg_salary', ascending = False))
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      93         return table.__finalize__(data, method="pivot_table")
#      94
# ---> 95     table = __internal_pivot_table(
#      96         data,
#      97         values,
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     162         values = list(values)
#     163
# --> 164     grouped = data.groupby(keys, observed=observed, sort=sort)
#     165     agged = grouped.agg(aggfunc)
#     166     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7719         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720         # "Union[bool, NoDefault]"; expected "bool"
# -> 7721         return DataFrameGroupBy(
#    7722             obj=self,
#    7723             keys=by,
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     880             from pandas.core.groupby.grouper import get_grouper
#     881
# --> 882             grouper, exclusions, obj = get_grouper(
#     883                 obj,
#     884                 keys,
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     875                     # non-unique columns; raise here to get the name in the
#     876                     # exception message
# --> 877                     raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     878                 exclusions.add(name)
#     879             elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'avg_salary' not 1-dimensional

# %%
pd.pivot_table(df_pivots, index="Revenue", columns='python_yn', values='avg_salary', aggfunc='count')
# Out:
# python_yn                             0     1
# Revenue
# $1 to $5 billion (USD)             61.0  29.0
# $1 to $5 million (USD)              NaN   2.0
# $10+ billion (USD)                259.0   7.0
# $100 to $500 million (USD)         41.0   3.0
# $25 to $100 million (USD)          34.0   NaN
# $5 to $10 billion (USD)            30.0   NaN
# $5 to $25 million (USD)             7.0   NaN
# $500 million to $1 billion (USD)   32.0   NaN
# -1                                 12.0   NaN
# Less than $1 million (USD)          NaN   2.0
# Unknown / Non-Applicable          223.0  41.0

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])
wc = WordCloud(background_color="white", random_state=1, stopwords=STOPWORDS, max_words=2000, width=800, height=1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda_data.csv')
