# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('clean_data_science_jobs_2.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21196\741178613.py in <module>
# ----> 1 df = pd.read_csv('clean_data_science_jobs_2.csv')
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#                  Job Title                         Salary Estimate  \
# 0       Jr. Data Scientist    Employer Provided Salary:$65K - $80K
# 1           Data Scientist   Employer Provided Salary:$60K - $140K
# 2           Data Scientist   Employer Provided Salary:$95K - $135K
# 3  Genomics Data Scientist  Employer Provided Salary:$100K - $125K
# 4           Data Scientist           $79K - $122K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0   Apply Statistical and Machine Learning metho...    -1.0
# 1  iOS: https://apps.apple.com/us/app/id155187173...     5.0
# 2  About Zest AI:\nZest AI has been perfecting AI...    -1.0
# 3  Description:\nCompany Summary\nAvellino, a glo...     3.0
# 4  Career Area:\nInformation Analytics\nJob Descr...     4.0
#
#                 Company Name    Location  Headquarters                 Size  \
# 0                 Net2Aspire      Remote            -1  51 to 200 Employees
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Rating  Headquarters      Founded  Competitors      hourly  \
# count  779.000000         779.0   779.000000        779.0  779.000000
# mean     3.619769          -1.0  1491.232349         -1.0    0.043646
# std      1.431592           0.0   829.760494          0.0    0.204437
# min     -1.000000          -1.0    -1.000000         -1.0    0.000000
# 25%      3.800000          -1.0  1754.000000         -1.0    0.000000
# 50%      4.000000          -1.0  1925.000000         -1.0    0.000000
# 75%      4.200000          -1.0  2001.000000         -1.0    0.000000
# max      5.000000          -1.0  2020.000000         -1.0    1.000000
#
#        employer_provided  min_salary  max_salary         age   python_yn  \
# count         779.000000  779.000000  779.000000  779.000000  779.000000
# mean            0.711168   93.621309  137.345315   56.061617    0.138639
# std             0.453511   21.390160   36.651631   70.039771    0.345792
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['age','avg_salary','Rating'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Rating')
# Out:
# <AxesSubplot:>

# %%
corr_df= df[['age','avg_salary','Rating', 'desc_len']].corr()

# %%
cmap = sns.diverging_palette(220,10,as_cmap=True)

sns.heatmap(corr_df,cmap=cmap, vmax=.3, center=0,
           square=True, linewidths=.5,cbar_kws={"shrink":.5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'job_state', 'company_text', 'python_yn', 'rstudio_yn',
       'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()

# %%
for i in df_cat[['Location', 'company_text']]:
    cat_num = df_cat[i].value_counts()[:20]
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary'],
#       dtype='object')

# %%
pd.pivot_table(df, index='job_simp', values='avg_salary')
# Out:
#                 avg_salary
# job_simp
# data scientist  115.483312

# %%
pd.pivot_table(df, index=['job_simp', 'seniority'], values='avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# data scientist jr          99.500000
#                na         113.414265
#                senior     152.226415

# %%
pd.pivot_table(df, index=['job_state', 'seniority'], values='avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                           avg_salary
# job_state      seniority
#  WA            senior     180.000000
#  New Jersey    jr         170.000000
#  Remote        senior     168.000000
#  NJ            senior     167.000000
#  FL            senior     147.500000
#  CA            senior     142.171875
#                na         135.347368
#  DC            na         125.644737
#  WA            na         125.500000
#  MD            na         118.750000
#  AZ            na         118.703125
#  Remote        na         111.789308
#  VA            na         110.236111
#  MO            na         110.000000
#  NY            na         108.557377
#  IN            na         105.750000
#  TX            na         105.687500
#  PA            na         105.666667
#  Florida       na         103.500000
#  NJ            na         101.100000
#  MI            na         100.659091
#  IL            na         100.500000
#  NC            na          96.934783
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'company_text', 'job_state', 'age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'avg_salary'],
#       dtype='object')

# %%
#rating, industry, sector, revenue, number of comp, hourly, employer provided, pytho, r, spark, aws, excel, Type of ournership
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided', 'python_yn', 'rstudio_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'Type of ownership', 'avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index=i, values='avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
#  4.9    180.000000
#  3.2    143.950000
#  4.8    141.000000
#  3.7    134.000000
#  3.6    132.111111
#  4.2    128.706186
#  3.9    122.548507
#  4.3    121.031250
#  4.0    118.720588
#  3.4    116.125000
#  4.5    114.192308
#  3.0    112.500000
#  3.8    108.250000
#  5.0    104.872093
# -1.0    102.246032
#  3.1    100.000000
#  4.1     98.162791
#  3.5     94.051020
#  4.7     79.500000
# Industry
#                                          avg_salary
# Industry
# Other Retail Stores                      221.500000
# Food & Beverage Manufacturing            170.000000
# Real Estate                              168.000000
# Staffing & Subcontracting                160.000000
# Airlines, Airports & Air Transportation  134.000000
# Enterprise Software & Network Solutions  133.500000
# Investment & Asset Management            133.428571
# Internet & Web Services                  132.889474
# Aerospace & Defense                      131.884615
# ...

# %%
pd.pivot_table(df_pivots, index="Revenue", columns='python_yn', values='avg_salary', aggfunc='count')
# Out:
# python_yn                             0     1
# Revenue
# $1 to $5 billion (USD)            102.0   NaN
# $1 to $5 million (USD)              2.0   NaN
# $10+ billion (USD)                220.0   7.0
# $100 to $500 million (USD)         45.0   2.0
# $25 to $100 million (USD)          14.0   NaN
# $5 to $10 billion (USD)            23.0   NaN
# $5 to $25 million (USD)             6.0   NaN
# $500 million to $1 billion (USD)   38.0   NaN
# -1                                  5.0   NaN
# Unknown / Non-Applicable          216.0  99.0

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])
wc = WordCloud(background_color="white", random_state=1, stopwords=STOPWORDS, max_words=2000, width=800, height=1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda_data.csv')
